# %%
#Kelompok 2
#Okta Fauzan, Yogi, Al Ahfaz Reza Ramdani, Ali Akbar
#Tugas Akhir Mata Kuliah "Big Data"
#Dosen Pengampu : Yudistira Bagus Pratama, M.Kom

import pandas as pd

# %%
df = pd.read_csv("D:\TES\Survei_Medsos.csv",index_col=0,encoding = 'ISO-8859-1')

# %%
print("======= 5 Data Pertama ======")
df.head(100)
# Out:
# ======= 5 Data Pertama ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa         WA         WA          < 5 menit
# Perempuan       Ibu Rumah Tangga  Instagram  Instagram        11-30 menit
# Laki-laki      Pelajar/Mahasiswa         WA  Instagram        31-60 menit
# ...                          ...        ...        ...                ...
# Laki-laki      Pelajar/Mahasiswa         WA  Instagram        11-30 menit
# Laki-laki             Wiraswasta         WA   Facebook          < 5 menit
# Perempuan      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa         WA  Instagram        11-30 menit
# Laki-laki      Pelajar/Mahasiswa         WA         WA        31-60 menit
#
# ...

# %%
print("======= 10 Data Terakhir ======")
df.tail(10)
# Out:
# ======= 10 Data Terakhir ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Perempuan      Pelajar/Mahasiswa         WA   Snapchat        11-30 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa       LINE  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# Perempuan      Pelajar/Mahasiswa         WA         WA        31-60 menit
# Laki-laki      Pelajar/Mahasiswa    Twitter    Twitter        11-30 menit
# Laki-laki      Pelajar/Mahasiswa       LINE       LINE            > 1 jam
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# Perempuan      Pelajar/Mahasiswa         WA  Instagram        11-30 menit
#
#               Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# Jenis_Kelamin
# ...

# %%
print("======= Menampilkan Data Secara Acak/Random ======")
df.sample()
# Out:
# ======= Menampilkan Data Secara Acak/Random ======
#                        Pekerjaan   Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Perempuan      Pelajar/Mahasiswa  Twitter    Twitter         5-10 menit
#
#               Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# Jenis_Kelamin
# Perempuan       < 30 menit                         3               3
#
#                Tidak_Bisa_Kontrol_Diri  Tidak_Sadar_Waktu  Fomo  Tanpa_Tujuan  \
# Jenis_Kelamin
# Perempuan                            3                  3     1             2
#
#                Terpikirkan Usaha_Melepaskan_Diri Kesulitan_Melepaskan_Diri  \
# Jenis_Kelamin
# Perempuan                2                Pernah                     Tidak
#
#               Butuh_Aplikasi Pernah_Memakai_Aplikasi_Pengaturan_Waktu
# Jenis_Kelamin
# Perempuan                 Ya                                    Tidak

# %%
print("======= Menghitung Data di Setiap Kolom ======")
df.count()
# Out:
# ======= Menghitung Data di Setiap Kolom ======
# Pekerjaan                                   118
# Sering                                      118
# Lupa_Waktu                                  118
# Waktu_Sekali_Pakai                          118
# Waktu_Harian                                118
# Mengganggu_Produktivitas                    118
# Membuang_Waktu                              118
# Tidak_Bisa_Kontrol_Diri                     118
# Tidak_Sadar_Waktu                           118
# Fomo                                        118
# Tanpa_Tujuan                                118
# Terpikirkan                                 118
# Usaha_Melepaskan_Diri                       118
# Kesulitan_Melepaskan_Diri                   117
# Butuh_Aplikasi                              118
# Pernah_Memakai_Aplikasi_Pengaturan_Waktu    118
# dtype: int64

# %%
print("======= Mengetahui Properti/Dimensi Dari Data(Jumlah baris/kolom)  ======")
df.shape[0]
# Out:
# ======= Mengetahui Properti/Dimensi Dari Data(Jumlah baris/kolom)  ======
# 118

# %%
print("======= Menghitung Data Dalam Kolom ======")
df.shape
# Out:
# ======= Menghitung Data Dalam Kolom ======
# (118, 16)

# %%
print("======= Menampilkan Tipe Data dari Kolom ======")
df.dtypes
# Out:
# ======= Menampilkan Tipe Data dari Kolom ======
# Pekerjaan                                   object
# Sering                                      object
# Lupa_Waktu                                  object
# Waktu_Sekali_Pakai                          object
# Waktu_Harian                                object
# Mengganggu_Produktivitas                     int64
# Membuang_Waktu                               int64
# Tidak_Bisa_Kontrol_Diri                      int64
# Tidak_Sadar_Waktu                            int64
# Fomo                                         int64
# Tanpa_Tujuan                                 int64
# Terpikirkan                                  int64
# Usaha_Melepaskan_Diri                       object
# Kesulitan_Melepaskan_Diri                   object
# Butuh_Aplikasi                              object
# Pernah_Memakai_Aplikasi_Pengaturan_Waktu    object
# dtype: object

# %%
print("======= Detail Data ======")
df.info()
# Out:
# ======= Detail Data ======
# <class 'pandas.core.frame.DataFrame'>
# Index: 118 entries, Laki-laki to Perempuan
# Data columns (total 16 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Pekerjaan                                 118 non-null    object
#  1   Sering                                    118 non-null    object
#  2   Lupa_Waktu                                118 non-null    object
#  3   Waktu_Sekali_Pakai                        118 non-null    object
#  4   Waktu_Harian                              118 non-null    object
#  5   Mengganggu_Produktivitas                  118 non-null    int64
#  6   Membuang_Waktu                            118 non-null    int64
#  7   Tidak_Bisa_Kontrol_Diri                   118 non-null    int64
#  8   Tidak_Sadar_Waktu                         118 non-null    int64
# ...

# %%
print("======= Menampilkan Semua Fungsi ======")
df.describe(include='all')
# Out:
# ======= Menampilkan Semua Fungsi ======
#                 Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# count                 118        118        118                118
# unique                  5          5          6                  5
# top     Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# freq                  111         44         83                 39
# mean                  NaN        NaN        NaN                NaN
# std                   NaN        NaN        NaN                NaN
# min                   NaN        NaN        NaN                NaN
# 25%                   NaN        NaN        NaN                NaN
# 50%                   NaN        NaN        NaN                NaN
# 75%                   NaN        NaN        NaN                NaN
# max                   NaN        NaN        NaN                NaN
#
#        Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# ...

# %%
print("======= Menampilkan Kolom Tertentu Berdasarkan Data Pertama ======")
df[['Pekerjaan', 'Sering', 'Lupa_Waktu']].head()
# Out:
# ======= Menampilkan Kolom Tertentu Berdasarkan Data Pertama ======
#                        Pekerjaan     Sering Lupa_Waktu
# Jenis_Kelamin
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram
# Perempuan      Pelajar/Mahasiswa         WA         WA
# Perempuan       Ibu Rumah Tangga  Instagram  Instagram
# Laki-laki      Pelajar/Mahasiswa         WA  Instagram

# %%
print("======= Filter Data (Mencari Data di Kolom Tertentu) ======")
df[(df.Pekerjaan == "Pelajar/Mahasiswa")].head()
# Out:
# ======= Filter Data (Mencari Data di Kolom Tertentu) ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa         WA         WA          < 5 menit
# Laki-laki      Pelajar/Mahasiswa         WA  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa       LINE         WA        11-30 menit
#
#               Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# Jenis_Kelamin
# Laki-laki          > 2 jam                         4               5
# Laki-laki      31-60 menit                         3               3
# Perempuan          > 3 jam                         3               4
# Laki-laki          > 2 jam                         4               5
# Laki-laki          > 3 jam                         2               2
#
# ...

# %%
print("======= Filter Data (Mencari Data di Kolom Tertentu(Menggabungkan Logika AND dan Operator CR)) ======")
df[(df.Pekerjaan == "Pelajar/Mahasiswa") & (df.Membuang_Waktu > 2)]
# Out:
# ======= Filter Data (Mencari Data di Kolom Tertentu(Menggabungkan Logika AND dan Operator CR)) ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa         WA         WA          < 5 menit
# Laki-laki      Pelajar/Mahasiswa         WA  Instagram        31-60 menit
# Perempuan      Pelajar/Mahasiswa       LINE  Instagram         5-10 menit
# ...                          ...        ...        ...                ...
# Laki-laki      Pelajar/Mahasiswa    Twitter    Twitter        11-30 menit
# Laki-laki      Pelajar/Mahasiswa       LINE       LINE            > 1 jam
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# ...

# %%
print("======= Filter Kolom yang Nilainya di tentukan ( Tanda ~ - >) ======")
df[ ~(df['Pekerjaan'].isin(['Laki-laki', 'Perempuan']))
  & (df['Membuang_Waktu'] > 2)
  ]
# Out:
# ======= Filter Kolom yang Nilainya di tentukan ( Tanda ~ - >) ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa         WA         WA          < 5 menit
# Perempuan       Ibu Rumah Tangga  Instagram  Instagram        11-30 menit
# Laki-laki      Pelajar/Mahasiswa         WA  Instagram        31-60 menit
# ...                          ...        ...        ...                ...
# Laki-laki      Pelajar/Mahasiswa    Twitter    Twitter        11-30 menit
# Laki-laki      Pelajar/Mahasiswa       LINE       LINE            > 1 jam
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# ...

# %%
print("======= Mengurutkan Data Berdasarkan Kolom ======")
df.sort_values('Sering').head(50)
# Out:
# ======= Mengurutkan Data Berdasarkan Kolom ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Laki-laki      Pelajar/Mahasiswa   Facebook   Facebook            > 1 jam
# Laki-laki      Pelajar/Mahasiswa   Facebook   Facebook            > 1 jam
# Laki-laki                Lainnya   Facebook   Facebook            > 1 jam
# Laki-laki      Pelajar/Mahasiswa   Facebook   Facebook         5-10 menit
# Perempuan      Pelajar/Mahasiswa   Facebook   Facebook         5-10 menit
# Perempuan      Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# Perempuan      Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# Perempuan      Pelajar/Mahasiswa  Instagram  Instagram            > 1 jam
# Laki-laki      Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit
# ...

# %%
print("======= Mengurutkan Data Berdasarkan Kolom(ascending) ======")
df.sort_values('Sering', ascending=False).head()
# Out:
# ======= Mengurutkan Data Berdasarkan Kolom(ascending) ======
#                        Pekerjaan Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Perempuan      Pelajar/Mahasiswa     WA  Instagram        31-60 menit
# Perempuan      Pelajar/Mahasiswa     WA  Instagram        11-30 menit
# Perempuan      Pelajar/Mahasiswa     WA  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa     WA    Twitter        11-30 menit
# Perempuan      Pelajar/Mahasiswa     WA         WA        11-30 menit
#
#               Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# Jenis_Kelamin
# Perempuan          > 3 jam                         2               3
# Perempuan          > 3 jam                         3               2
# Perempuan          > 3 jam                         3               3
# Perempuan          > 2 jam                         3               4
# Perempuan          > 2 jam                         3               2
#
# ...

# %%
print("======= Mengurutkan Data Berdasarkan Kolom (dua kolom) ======")
df.sort_values(['Pekerjaan', 'Sering']).head()
# Out:
# ======= Mengurutkan Data Berdasarkan Kolom (dua kolom) ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Perempuan       Ibu Rumah Tangga  Instagram  Instagram        11-30 menit
# Laki-laki                Lainnya   Facebook   Facebook            > 1 jam
# Laki-laki                Lainnya  Instagram  Instagram         5-10 menit
# Perempuan                Lainnya         WA  Instagram        11-30 menit
# Laki-laki      Pelajar/Mahasiswa   Facebook   Facebook            > 1 jam
#
#               Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# Jenis_Kelamin
# Perempuan          > 3 jam                         4               5
# Laki-laki          > 3 jam                         2               1
# Laki-laki          > 2 jam                         2               3
# Perempuan          > 2 jam                         3               4
# Laki-laki          > 3 jam                         1               3
#
# ...

# %%
print("======= Mengurutkan Data Berdasarkan Kolom (dua kolom)(ascending) ======")
df.sort_values(['Sering', 'Lupa_Waktu'], ascending=False).head()
# Out:
# ======= Mengurutkan Data Berdasarkan Kolom (dua kolom)(ascending) ======
#                        Pekerjaan Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Perempuan      Pelajar/Mahasiswa     WA         WA          < 5 menit
# Laki-laki      Pelajar/Mahasiswa     WA         WA         5-10 menit
# Laki-laki      Pelajar/Mahasiswa     WA         WA        31-60 menit
# Perempuan      Pelajar/Mahasiswa     WA         WA        11-30 menit
# Perempuan      Pelajar/Mahasiswa     WA         WA        11-30 menit
#
#               Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# Jenis_Kelamin
# Perempuan          > 3 jam                         3               4
# Laki-laki          > 2 jam                         4               4
# Laki-laki          > 1 jam                         2               4
# Perempuan          > 2 jam                         3               2
# Perempuan          > 3 jam                         4               5
#
# ...

# %%
print("======= Mengurutkan Data Berdasarkan Kolom (dua kolom)(ascending) ======")
df.sort_values(['Pekerjaan', 'Membuang_Waktu'], ascending=[0, 1]).head()
# Out:
# ======= Mengurutkan Data Berdasarkan Kolom (dua kolom)(ascending) ======
#                        Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai  \
# Jenis_Kelamin
# Laki-laki             Wiraswasta         WA   Facebook          < 5 menit
# Perempuan          Tidak bekerja  Instagram  Instagram        31-60 menit
# Perempuan          Tidak bekerja         WA  Instagram         5-10 menit
# Perempuan      Pelajar/Mahasiswa  Instagram  Instagram            > 1 jam
# Perempuan      Pelajar/Mahasiswa  Instagram  Instagram            > 1 jam
#
#               Waktu_Harian  Mengganggu_Produktivitas  Membuang_Waktu  \
# Jenis_Kelamin
# Laki-laki       < 30 menit                         4               1
# Perempuan          > 1 jam                         3               3
# Perempuan      31-60 menit                         3               5
# Perempuan          > 3 jam                         1               1
# Perempuan          > 3 jam                         4               1
#
# ...

# %%
print("======= Mengatur Indeks dari dataframe ======")
df.set_index('Pekerjaan')
# Out:
# ======= Mengatur Indeks dari dataframe ======
#                       Sering Lupa_Waktu Waktu_Sekali_Pakai Waktu_Harian  \
# Pekerjaan
# Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit      > 2 jam
# Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit  31-60 menit
# Pelajar/Mahasiswa         WA         WA          < 5 menit      > 3 jam
# Ibu Rumah Tangga   Instagram  Instagram        11-30 menit      > 3 jam
# Pelajar/Mahasiswa         WA  Instagram        31-60 menit      > 2 jam
# ...                      ...        ...                ...          ...
# Pelajar/Mahasiswa    Twitter    Twitter        11-30 menit      > 1 jam
# Pelajar/Mahasiswa       LINE       LINE            > 1 jam      > 3 jam
# Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit      > 2 jam
# Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit      > 1 jam
# Pelajar/Mahasiswa         WA  Instagram        11-30 menit      > 1 jam
#
# ...

# %%
print("======= Mengatur Indeks dari dataframe ======")
df.reset_index(drop=True)
# Out:
# ======= Mengatur Indeks dari dataframe ======
#              Pekerjaan     Sering Lupa_Waktu Waktu_Sekali_Pakai Waktu_Harian  \
# 0    Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit      > 2 jam
# 1    Pelajar/Mahasiswa  Instagram  Instagram         5-10 menit  31-60 menit
# 2    Pelajar/Mahasiswa         WA         WA          < 5 menit      > 3 jam
# 3     Ibu Rumah Tangga  Instagram  Instagram        11-30 menit      > 3 jam
# 4    Pelajar/Mahasiswa         WA  Instagram        31-60 menit      > 2 jam
# ..                 ...        ...        ...                ...          ...
# 113  Pelajar/Mahasiswa    Twitter    Twitter        11-30 menit      > 1 jam
# 114  Pelajar/Mahasiswa       LINE       LINE            > 1 jam      > 3 jam
# 115  Pelajar/Mahasiswa  Instagram  Instagram        31-60 menit      > 2 jam
# 116  Pelajar/Mahasiswa  Instagram  Instagram        11-30 menit      > 1 jam
# 117  Pelajar/Mahasiswa         WA  Instagram        11-30 menit      > 1 jam
# ...
